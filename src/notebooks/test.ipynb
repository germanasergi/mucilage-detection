# %%
import os
from urllib.parse import urlparse
import random
import yaml
from shapely.geometry import box, mapping
from eopf.store.convert import convert
import boto3
import pystac_client
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import numpy as np

import glob
import natsort
import xarray as xr
import sys

from eopf.common.constants import OpeningMode
from eopf.common.file_utils import AnyPath
# Out:
# /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/diagnostics/nvml.py:13: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml

# %% [markdown]
# # Functions needed for the test

# %%
def load_config(config_path):
    """Load configuration from YAML file"""
    with open(config_path, 'r') as file:
        return yaml.safe_load(file)

def setup_environment(config):
    """Set up environment variables and directories for the dataset"""
    # Keep these from environment variables
    ACCESS_KEY_ID = 'MLTFR0SO1BCGFUV70UH5'
    SECRET_ACCESS_KEY = 'vhy1H1QErCukTooZgugD3YJl76jWqm3a5k1CpN51'

    # Get other parameters from config
    ENDPOINT_URL = config['endpoint_url']
    ENDPOINT_STAC = config['endpoint_stac']
    BUCKET_NAME = config['bucket_name']
    DATASET_VERSION = config['dataset_version']
    BASE_DIR = config['base_dir']
    DATASET_DIR = f"{BASE_DIR}/{DATASET_VERSION}"
    BANDS = config['bands']

    # Setup connector
    connector = S3Connector(
        endpoint_url=ENDPOINT_URL,
        access_key_id=ACCESS_KEY_ID,
        secret_access_key=SECRET_ACCESS_KEY,
        region_name='default')

    buckets = connector.list_buckets()
    print("Available buckets:", buckets)

    s3 = connector.get_s3_resource()
    s3_client = connector.get_s3_client()

    return {
        'ACCESS_KEY_ID': ACCESS_KEY_ID,
        'SECRET_ACCESS_KEY': SECRET_ACCESS_KEY,
        'ENDPOINT_URL': ENDPOINT_URL,
        'ENDPOINT_STAC':ENDPOINT_STAC,
        'BUCKET_NAME': BUCKET_NAME,
        'DATASET_DIR': DATASET_DIR,
        'BANDS': BANDS,
        's3_client': connector.get_s3_client(),
        's3': connector.get_s3_resource()
    }


def download(bucket, product: str, target: str = "") -> str:
    if not product.endswith('/'):
        product += '/'
    files = list(bucket.objects.filter(Prefix=product))
    if not files:
        raise FileNotFoundError(f"Could not find any files for {product}")
    safe_dir = os.path.basename(product.rstrip('/'))
    if not safe_dir.endswith('.SAFE'):
        raise ValueError(f"Expected a .SAFE directory, got: {safe_dir}")
    local_path = os.path.join(target, safe_dir)
    os.makedirs(local_path, exist_ok=True)

    for file in files:
        if file.key.endswith('/'):
            continue
        relative_path = os.path.relpath(file.key, product)
        local_file_path = os.path.join(local_path, relative_path)
        os.makedirs(os.path.dirname(local_file_path), exist_ok=True)
        bucket.download_file(file.key, local_file_path)
    return local_path


def get_chunk_info(data_tree, band, res):
    """
    Extract chunk size and number of chunks from a dataset.

    Parameters:
    - data_tree: xarray.DataTree
    - band: str, e.g. "b03"
    - resolution: str, y-dimension name (e.g. "y_10m")
    - x_res: str, x-dimension name (e.g. "x_10m")

    Returns:
    - chunk_size_y: int
    - chunk_size_x: int
    - nb_chunks_y: int
    - nb_chunks_x: int
    """
    res_key = f"r{res}"
    y_res = f"y"
    x_res = f"x"
    data_tree = data_tree.measurements.reflectance[res_key]

    chunk_size_y = data_tree[band].chunksizes[y_res][0]
    chunk_size_x = data_tree[band].chunksizes[x_res][0]
    nb_chunks_y = len(data_tree[band].chunksizes[y_res])
    nb_chunks_x = len(data_tree[band].chunksizes[x_res])

    print(f"Chunk size: y={chunk_size_y}, x={chunk_size_x}")
    print(f"Number of chunks: y={nb_chunks_y}, x={nb_chunks_x}")

    return chunk_size_y, chunk_size_x, nb_chunks_y, nb_chunks_x


def extract_s3_path_from_url(url):
    """
    Extracts the S3 object path from an S3 URL or URI.

    This function parses S3 URLs/URIs and returns just the object path portion,
    removing the protocol (s3://), bucket name, and any leading slashes.

    Args:
        url (str): The full S3 URI (e.g., 's3://eodata/path/to/file.jp2')

    Returns:
        str: The S3 object path (without protocol, bucket name and leading slashes)
    """
    # If it's not an S3 URI, return it unchanged
    if not url.startswith('s3://'):
        return url

    # Parse the S3 URI
    parsed_url = urlparse(url)

    # Ensure this is an S3 URL
    if parsed_url.scheme != 's3':
        raise ValueError(f"URL {url} is not an S3 URL")

    # Extract the path without leading slashes
    object_path = parsed_url.path.lstrip('/')

    return object_path

# %%
class S3Connector:
    """A clean connector for S3-compatible storage services"""

    def __init__(self, endpoint_url, access_key_id,
                 secret_access_key, region_name='default'):
        """Initialize the S3Connector with connection parameters"""
        self.endpoint_url = endpoint_url
        self.access_key_id = access_key_id
        self.secret_access_key = secret_access_key
        self.region_name = region_name

        # Create session
        self.session = boto3.session.Session()

        # Initialize S3 resource
        self.s3 = self.session.resource(
            's3',
            endpoint_url=self.endpoint_url,
            aws_access_key_id=self.access_key_id,
            aws_secret_access_key=self.secret_access_key,
            region_name=self.region_name
        )

        # Initialize S3 client
        self.s3_client = self.session.client(
            's3',
            endpoint_url=self.endpoint_url,
            aws_access_key_id=self.access_key_id,
            aws_secret_access_key=self.secret_access_key,
            region_name=self.region_name
        )

    def get_s3_client(self):
        """Get the boto3 S3 client"""
        return self.s3_client

    def get_s3_resource(self):
        """Get the boto3 S3 resource"""
        return self.s3

    def get_bucket(self, bucket_name):
        """Get a specific bucket by name"""
        return self.s3.Bucket(bucket_name)

    def list_buckets(self):
        """List all available buckets"""
        response = self.s3_client.list_buckets()
        if 'Buckets' in response:
            return [bucket['Name'] for bucket in response['Buckets']]
        return []

# %%
def plot_all_chunks(data_tree, band, res, chunk_size_y, chunk_size_x, nb_chunks_y, nb_chunks_x, cmap="viridis", verbose= True, figsize_scale=3):
    """
    Plot all chunks of a given band and resolution.

    Parameters:
    - data_tree: xarray Dataset (e.g. dt.measurements.reflectance.r20m)
    - band: str, band name (e.g. "b05")
    - cmap: str, matplotlib colormap
    - figsize_scale: int, scales the figure size (default is 3)
    """
    res_key = f"r{res}"
    y_res = 'y' #MODIFIED
    x_res = 'x'
    data_tree = data_tree.measurements.reflectance[res_key]
    # Set up plot grid
    fig, axes = plt.subplots(
        nb_chunks_y, nb_chunks_x,
        figsize=(figsize_scale * nb_chunks_x, figsize_scale * nb_chunks_y)
    )

    # Plot each chunk
    for i in range(nb_chunks_y):
        for j in range(nb_chunks_x):
            ax = axes[i, j] if nb_chunks_y > 1 else axes[j]
            y_start = i * chunk_size_y
            x_start = j * chunk_size_x
            chunk = data_tree[band].isel(
                {y_res: slice(y_start, y_start + chunk_size_y),
                 x_res: slice(x_start, x_start + chunk_size_x)}
            ).load()
            ax.imshow(chunk, cmap=cmap, vmin=float(chunk.min()), vmax=float(chunk.max()))
            ax.set_title(f"Chunk ({i},{j})")
            ax.axis("off")
    if verbose:
        plt.tight_layout()
        plt.savefig("chunks_plot.png", dpi=300)

# %% [markdown]
# # Testing

# %%
# Configuration parameters

config_path = '/home/ubuntu/mucilage_pipeline/mucilage-detection/src/cfg/config_dataset.yaml'
config = load_config(config_path)
env = setup_environment(config)
catalog = pystac_client.Client.open(env['ENDPOINT_STAC'])

# Extract bbox from config query
bbox = config['query']['bbox']  # [min_lon, min_lat, max_lon, max_lat]

# Create GeoJSON polygon from bbox
polygon_geojson = mapping(box(*bbox))
start_date = config['query']['start_date']
end_date = config['query']['end_date']
max_cloud_cover = config['query']['max_cloud_cover']

datetime_range = f"{start_date}/{end_date}"

# Perform search
items = catalog.search(
    collections=['sentinel-2-l2a'],
    intersects=polygon_geojson,
    datetime=datetime_range,
    query=[f"eo:cloud_cover<{max_cloud_cover}"]
)
# Out:
# Available buckets: ['DIAS', 'EODATA']

# %%
# Download all the files as .SAFE

items_list = list(items.items())
print(f"Found {len(items_list)} matching products.")

if not items_list:
    print("No items found")

zarr_paths = []
for item in items_list:
    product_url, _ = os.path.split(item.assets['safe_manifest'].href)
    product_url = extract_s3_path_from_url(product_url)

    print(f"Downloading: {product_url}")
    #safe_path = download(bucket, product_url, target=os.getcwd())
# Out:
# Found 22 matching products.
# Downloading: Sentinel-2/MSI/L2A/2024/07/28/S2B_MSIL2A_20240728T095549_N0511_R122_T33TUL_20240728T114034.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/28/S2B_MSIL2A_20240728T095549_N0511_R122_T33TUK_20240728T114034.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/28/S2B_MSIL2A_20240728T095549_N0511_R122_T32TQR_20240728T114034.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/28/S2B_MSIL2A_20240728T095549_N0511_R122_T32TQQ_20240728T114034.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/26/S2A_MSIL2A_20240726T100601_N0511_R022_T33TUL_20240726T193850.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/26/S2A_MSIL2A_20240726T100601_N0511_R022_T33TUK_20240726T193850.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/26/S2A_MSIL2A_20240726T100601_N0511_R022_T32TQR_20240726T193850.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/26/S2A_MSIL2A_20240726T100601_N0511_R022_T32TQQ_20240726T193850.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/23/S2A_MSIL2A_20240723T100031_N0511_R122_T33TUK_20240723T155949.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/23/S2A_MSIL2A_20240723T100031_N0511_R122_T32TQQ_20240723T155949.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/21/S2B_MSIL2A_20240721T100559_N0510_R022_T33TUL_20240721T125344.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/21/S2B_MSIL2A_20240721T100559_N0510_R022_T33TUK_20240721T125344.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/21/S2B_MSIL2A_20240721T100559_N0510_R022_T32TQR_20240721T125344.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/21/S2B_MSIL2A_20240721T100559_N0510_R022_T32TQQ_20240721T125344.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/18/S2B_MSIL2A_20240718T095549_N0510_R122_T33TUL_20240718T124043.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/18/S2B_MSIL2A_20240718T095549_N0510_R122_T33TUK_20240718T124043.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/18/S2B_MSIL2A_20240718T095549_N0510_R122_T32TQR_20240718T124043.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/18/S2B_MSIL2A_20240718T095549_N0510_R122_T32TQQ_20240718T124043.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/16/S2A_MSIL2A_20240716T100601_N0510_R022_T33TUL_20240716T160254.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/16/S2A_MSIL2A_20240716T100601_N0510_R022_T33TUK_20240716T160254.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/16/S2A_MSIL2A_20240716T100601_N0510_R022_T32TQR_20240716T160254.SAFE
# Downloading: Sentinel-2/MSI/L2A/2024/07/16/S2A_MSIL2A_20240716T100601_N0510_R022_T32TQQ_20240716T160254.SAFE

# %%
for item in items.item_collection():
    print(item.id)  # usually includes tile ID (e.g., TPF or TPE)
    print(item.geometry)
    print(item.assets['safe_manifest'].href)
# Out:
# S2B_MSIL2A_20240728T095549_N0511_R122_T33TUL_20240728T114034
# {'type': 'Polygon', 'coordinates': [[[12.424645070169124, 45.832610704010406], [12.428970892050708, 45.84510488113258], [12.479821543426572, 45.991651764295], [12.492333987637313, 46.02560721362705], [13.834108089722305, 46.0476276229589], [13.854365464520265, 45.05951360004942], [12.460785793001175, 45.037023116804335], [12.424645070169124, 45.832610704010406]]]}
# s3://eodata/Sentinel-2/MSI/L2A/2024/07/28/S2B_MSIL2A_20240728T095549_N0511_R122_T33TUL_20240728T114034.SAFE/manifest.safe
# S2B_MSIL2A_20240728T095549_N0511_R122_T33TUK_20240728T114034
# {'type': 'Polygon', 'coordinates': [[[12.456860516996768, 45.12551356202371], [13.852592618382664, 45.148073182871244], [13.87191870410008, 44.15979663371134], [12.499651613106883, 44.137996748196564], [12.456860516996768, 45.12551356202371]]]}
# s3://eodata/Sentinel-2/MSI/L2A/2024/07/28/S2B_MSIL2A_20240728T095549_N0511_R122_T33TUK_20240728T114034.SAFE/manifest.safe
# S2B_MSIL2A_20240728T095549_N0511_R122_T32TQR_20240728T114
# s3://eodata/Sentinel-2/MSI/L2A/2024/07/16/S2A_MSIL2A_20240716T100601_N0510_R022_T32TQQ_20240716T160254.SAFE/manifest.safe

# %%
# Download one .SAFE then convert into .zarr

selected_item = random.choice(items.item_collection())
selected_item = list(items.item_collection())[2]
#safe_filename = download(bucket, product_url, target=".")
product_url , _ = os.path.split(selected_item.assets['safe_manifest'].href)
# Replace .SAFE with .zarr
zarr_filename =  os.path.split(product_url)[1].replace('.SAFE', '.zarr')
# Join the current directory path with the new filename
data_dir = '/home/ubuntu/mucilage_pipeline/mucilage-detection/data'
zarr_path = os.path.join(data_dir, zarr_filename)
#convert(safe_filename, zarr_path, mask_and_scale=True)

# %%
print(product_url)
# Out:
# s3://eodata/Sentinel-2/MSI/L2A/2024/07/28/S2B_MSIL2A_20240728T095549_N0511_R122_T32TQR_20240728T114034.SAFE

# %%
# Convert into .zarr on the flight

S3_CONFIG = {
    "key": env['ACCESS_KEY_ID'], # EDIT WITH YOUR S3 KEY
    "secret": env['SECRET_ACCESS_KEY'], # EDIT WITH YOUR S3 SECRET KEY
    "client_kwargs": { "endpoint_url": env['ENDPOINT_URL'], "region_name": "default"} # EDIT WITH YOUR CLIENT_KWARGS
}
# Add this parameter if you want to overwrite the output of the conversion if it already exists
target_store_config = dict(mode=OpeningMode.CREATE_OVERWRITE)

# For the zarr store we don't need to add the storage_options argument because we want to write the target product locally
convert(AnyPath(product_url, **S3_CONFIG), zarr_path, target_store_kwargs=target_store_config)
# Out:
# INFO:eopf.daskconfig.dask_context_manager:Initialising an ClusterType.LOCAL cluster with client conf : {} ,cluster config {'n_workers': 1} and dask config {}
# INFO:eopf.daskconfig.dask_context_manager:DASK Cluster : LocalCluster(619f1647, 'tcp://127.0.0.1:33399', workers=1, threads=8, memory=23.47 GiB)
# INFO:eopf.daskconfig.dask_context_manager:Dask Client : <Client: 'tcp://127.0.0.1:33399' processes=1 threads=8, memory=23.47 GiB>
# INFO:eopf.daskconfig.dask_context_manager:Dask dashboard address: http://127.0.0.1:8787/status
# INFO:eopf.store.convert:Converting eodata/Sentinel-2/MSI/L2A/2024/07/28/S2B_MSIL2A_20240728T095549_N0511_R122_T32TQR_20240728T114034.SAFE to /home/ubuntu/mucilage_pipeline/mucilage-detection/data/S2B_MSIL2A_20240728T095549_N0511_R122_T32TQR_20240728T114034.zarr
# INFO:eopf.store.safe:Found product type : S02MSIL2A with processing version: 05.00
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# ECCODES ERROR   :  unable to represent the step in h
#                     Hint: try changing the step units
# INFO:eopf.store.convert:EOProduct S2B_MSIL2A_20240728T095549_N0511_R122_T32TQR_20240728T114034 successfully loaded, starting to write to /home/ubuntu/mucilage_pipeline/mucilage-detection/data/S2B_MSIL2A_20240728T095549_N0511_R122_T32TQR_20240728T114034.zarr.zarr
# /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/dask/array/chunk.py:278: RuntimeWarning: invalid value encountered in cast
#   return x.astype(astype_dtype, **kwargs)
# WARNING:distributed.scheduler:Removing worker 'tcp://127.0.0.1:33287' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('store-map-ff457b4254bc3044ef166050ca033849', 5, 5), ('getitem-c532a488b0d874b670132c3892a94697', 0, 0), ('rechunk-split-e0b2b0b54087e833ea506d8472bcf827', 47), ('_block_pack_bit-85da9640f2fa108989656ab8eca8f44e', 0, 0), ('store-map-620a5382967932d68b940449892bee2b', 0, 5), '_finalize_store-232da800-a6bc-4f9f-9a5e-1ee0906d8350', ('store-map-e949090e4111790425f3b2eceffdcced', 5, 5), ('store-map-dc0108903ee029cc6f0734f64cd282f3', 4, 5), ('store-map-dc0108903ee029cc6f0734f64cd282f3', 5, 4), ('store-map-dc0108903ee029cc6f0734f64cd282f3', 3, 4), ('store-map-620a5382967932d68b940449892bee2b', 5, 4), ('store-map-984419614fe9e99a5020c0e226719695', 0, 1), '_finalize_store-11c4cc8a-e508-4093-a34e-fa524a7aeb75', ('_block_pack_bit-f48c10acfd2143a4d4c0b3cdebb320ac', 0, 0), ('getitem-e8e12dc6d1a0741ecc2e7c4bbeb53f3b', 0, 0), ('store-map-620a5382967932d68b940449892bee2b', 2, 5), ('getitem-39c5c53d4e71283479283cbca15592f9', 0, 0), ('_block_pack_bit-00150628ed5b24d9ad8b0dca8469f24a', 0, 0), ('getitem-881dfd61d0a40979a76ab6086d1fa40d', 0, 0), ('store-map-984419614fe9e99a5020c0e226719695', 2, 1), ('store-map-fa1c450b97b5b444ec5547cfe1fcc087',
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5936, in handle_worker
#     await self.handle_stream(comm=comm, extra={"worker": worker})
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 1053, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5801, in handle_task_finished
#     self.stimulus_queue_slots_maybe_opened(stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5024, in stimulus_queue_slots_maybe_opened
#     self.transitions({qts.key: "processing"}, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2807, in _transition_queued_processing
#     return self._add_to_processing(ts, ws, stimulus_id=stimulus_id)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 3209, in _add_to_processing
#     ws.add_to_processing(ts)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 744, in add_to_processing
#     assert dts.who_has
# AssertionError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# ERROR:distributed.scheduler:<TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5936, in handle_worker
#     await self.handle_stream(comm=comm, extra={"worker": worker})
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 1053, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5801, in handle_task_finished
#     self.stimulus_queue_slots_maybe_opened(stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5024, in stimulus_queue_slots_maybe_opened
#     self.transitions({qts.key: "processing"}, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2807, in _transition_queued_processing
#     return self._add_to_processing(ts, ws, stimulus_id=stimulus_id)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 3209, in _add_to_processing
#     ws.add_to_processing(ts)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 744, in add_to_processing
#     assert dts.who_has
# AssertionError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/utils.py", line 832, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5307, in remove_worker
#     self.transitions(recommendations, stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# ERROR:distributed.scheduler:<TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5936, in handle_worker
#     await self.handle_stream(comm=comm, extra={"worker": worker})
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 1053, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5801, in handle_task_finished
#     self.stimulus_queue_slots_maybe_opened(stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5024, in stimulus_queue_slots_maybe_opened
#     self.transitions({qts.key: "processing"}, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2807, in _transition_queued_processing
#     return self._add_to_processing(ts, ws, stimulus_id=stimulus_id)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 3209, in _add_to_processing
#     ws.add_to_processing(ts)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 744, in add_to_processing
#     assert dts.who_has
# AssertionError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/utils.py", line 832, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 4443, in add_worker
#     await self.handle_worker(comm, address)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5940, in handle_worker
#     await self.remove_worker(
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/utils.py", line 832, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5307, in remove_worker
#     self.transitions(recommendations, stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# ERROR:distributed.core:Exception while handling op register-worker
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5936, in handle_worker
#     await self.handle_stream(comm=comm, extra={"worker": worker})
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 1053, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5801, in handle_task_finished
#     self.stimulus_queue_slots_maybe_opened(stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5024, in stimulus_queue_slots_maybe_opened
#     self.transitions({qts.key: "processing"}, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2807, in _transition_queued_processing
#     return self._add_to_processing(ts, ws, stimulus_id=stimulus_id)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 3209, in _add_to_processing
#     ws.add_to_processing(ts)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 744, in add_to_processing
#     assert dts.who_has
# AssertionError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 970, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/utils.py", line 832, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 4443, in add_worker
#     await self.handle_worker(comm, address)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5940, in handle_worker
#     await self.remove_worker(
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/utils.py", line 832, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5307, in remove_worker
#     self.transitions(recommendations, stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-57891' coro=<Server._handle_comm() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py:876> exception=KeyError(<TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>)>
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5936, in handle_worker
#     await self.handle_stream(comm=comm, extra={"worker": worker})
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 1053, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5801, in handle_task_finished
#     self.stimulus_queue_slots_maybe_opened(stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5024, in stimulus_queue_slots_maybe_opened
#     self.transitions({qts.key: "processing"}, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2807, in _transition_queued_processing
#     return self._add_to_processing(ts, ws, stimulus_id=stimulus_id)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 3209, in _add_to_processing
#     ws.add_to_processing(ts)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 744, in add_to_processing
#     assert dts.who_has
# AssertionError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 970, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/utils.py", line 832, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 4443, in add_worker
#     await self.handle_worker(comm, address)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5940, in handle_worker
#     await self.remove_worker(
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/utils.py", line 832, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5307, in remove_worker
#     self.transitions(recommendations, stimulus_id=stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# 2025-08-12 07:29:18,015 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_rasterio-6fa68e7acea92dda7b495ff5b1c61098<this-array>-6160e005499699b3f3909e2dedd55603', 5, 0, 0))" coro=<Worker.execute() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-08-12 07:29:18,015 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_rasterio-6fa68e7acea92dda7b495ff5b1c61098<this-array>-6160e005499699b3f3909e2dedd55603', 7, 0, 0))" coro=<Worker.execute() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-08-12 07:29:18,015 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_rasterio-6fa68e7acea92dda7b495ff5b1c61098<this-array>-6160e005499699b3f3909e2dedd55603', 1, 0, 0))" coro=<Worker.execute() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-08-12 07:29:18,015 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_rasterio-6fa68e7acea92dda7b495ff5b1c61098<this-array>-6160e005499699b3f3909e2dedd55603', 4, 0, 0))" coro=<Worker.execute() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-08-12 07:29:18,015 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_rasterio-6fa68e7acea92dda7b495ff5b1c61098<this-array>-6160e005499699b3f3909e2dedd55603', 6, 0, 0))" coro=<Worker.execute() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-08-12 07:29:18,015 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('store-map-59f06e4259af0727b3d76a5fcd281743', 5, 4))" coro=<Worker.execute() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2025-08-12 07:29:18,015 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('open_rasterio-6fa68e7acea92dda7b495ff5b1c61098<this-array>-6160e005499699b3f3909e2dedd55603', 2, 0, 0))" coro=<Worker.execute() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# ERROR:distributed.scheduler:Error transitioning ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) from 'queued' to 'released'
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# ERROR:distributed.scheduler:Error transitioning ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) from 'queued' to 'forgotten'
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1964, in _transition
#     a_recs, a_cmsgs, a_wmsgs = self._transition(
#                                ^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# ERROR:distributed.core:Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 970, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5715, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 1053, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5743, in remove_client
#     self.client_releases_keys(
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5432, in client_releases_keys
#     self.transitions(recommendations, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1964, in _transition
#     a_recs, a_cmsgs, a_wmsgs = self._transition(
#                                ^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-36098' coro=<Server._handle_comm() done, defined at /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py:876> exception=KeyError(<TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>)>
# Traceback (most recent call last):
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 970, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5715, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/core.py", line 1053, in handle_stream
#     handler(**merge(extra, msg))
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5743, in remove_client
#     self.client_releases_keys(
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 5432, in client_releases_keys
#     self.transitions(recommendations, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 7991, in transitions
#     self._transitions(recommendations, client_msgs, worker_msgs, stimulus_id)
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2065, in _transitions
#     new_recs, new_cmsgs, new_wmsgs = self._transition(key, finish, stimulus_id)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1964, in _transition
#     a_recs, a_cmsgs, a_wmsgs = self._transition(
#                                ^^^^^^^^^^^^^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 1958, in _transition
#     recommendations, client_msgs, worker_msgs = func(
#                                                 ^^^^^
#   File "/home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/scheduler.py", line 2792, in _transition_queued_released
#     self.queued.remove(ts)
#   File "<frozen _collections_abc>", line 696, in remove
# KeyError: <TaskState ('rechunk-split-rechunk-merge-6ec0298d32212214d6c80dfddd41497b', 3, 4) queued>
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[18], line 12
#       9 target_store_config = dict(mode=OpeningMode.CREATE_OVERWRITE)
#      11 # For the zarr store we don't need to add the storage_options argument because we want to write the target product locally
# ---> 12 convert(AnyPath(product_url, **S3_CONFIG), zarr_path, target_store_kwargs=target_store_config)
#
# File /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/eopf/store/convert.py:174, in convert(source_path, target_path, target_format, mask_and_scale, source_store_kwargs, target_store_kwargs)
#     172 mode: str = target_store_kwargs.get("mode", "w+")
#     173 target_store.open(mode=mode)
# --> 174 target_store[product_name] = eop
#     175 target_store.close()
#     177 LOGGER.info("Conversion finished")
#
# File /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/eopf/store/zarr.py:742, in EOZarrStore.__setitem__(self, _EOZarrStore__key, _EOZarrStore__value)
#     740 if isinstance(eo_obj, EOProduct):
#     741     eo_obj.update_variables_short_names()
# --> 742     self._write_eog(group_fspath, group_fspath.to_zarr_store(), eo_obj)
#     743 else:
#     744     self._write_eoc(group_fspath, eo_obj)
#
# File /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/eopf/store/zarr.py:646, in EOZarrStore._write_eog(self, group_anypath, group_fsstore, eo_obj, sub_group_prefix, level)
#     644 self._consolidate_list.append(group_fsstore)
#     645 if not self._delayed_consolidate:
# --> 646     self.dask_flush()
#
# File /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/eopf/store/zarr.py:358, in EOZarrStore.dask_flush(self)
#     356 def dask_flush(self) -> None:
#     357     if len(self._futures_list) != 0:
# --> 358         dask_utils.wait_and_get_results(self._futures_list)
#     359         self._futures_list = []
#     360     for fs in self._consolidate_list:
#
# File /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/eopf/daskconfig/dask_utils.py:305, in wait_and_get_results(futures, cancel_at_first_error, **kwargs)
#     303 client = get_distributed_client()
#     304 if client is not None:
# --> 305     for future in as_completed(real_futures.values(), timeout=timeout):
#     306         index = next(i for i, f in real_futures.items() if f == future)  # Find correct index
#     307         if isinstance(index, int) and int is not None:
#
# File /home/ubuntu/.conda/envs/eopf/lib/python3.11/site-packages/distributed/client.py:5688, in as_completed.__next__(self)
#    5686 while self.queue.empty():
#    5687     if self._deadline.expired:
# -> 5688         raise TimeoutError()
#    5689     if self.is_empty():
#    5690         raise StopIteration()
#
# TimeoutError:

# %%
# Load zarr datatree

dt = xr.open_datatree('/home/ubuntu/mucilage_pipeline/DeltaTwin/data/target/S2C_MSIL2A_20250807T100041_N0511_R122_T33TUJ_20250807T122013.zarr', engine="zarr", mask_and_scale=False, chunks={})
ds = dt.measurements.reflectance

# %%
# Plot RGB

rgb = np.dstack([
    ds['r10m']['b04'].values,
    ds['r10m']['b03'].values,
    ds['r10m']['b02'].values
])
# Plot
plt.figure(figsize=(12, 8))
plt.imshow(rgb)
plt.axis('off')
plt.title('Sentinel-2 RGB Composite')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.0999..2.028].

# %%
print(selected_item.id)
print("bbox:", selected_item.bbox)
print("geometry area (deg2):", selected_item.geometry)  # you can inspect geometry

# compute approximate area (km^2) using shapely + proj (optional)
from shapely.geometry import shape
from pyproj import Transformer
geom = shape(selected_item.geometry)
print("geom bounds:", geom.bounds)
# Out:
# S2B_MSIL2A_20240728T095549_N0511_R122_T33TUK_20240728T114034
# bbox: [12.456861, 44.137997, 13.871919, 45.148073]
# geometry area (deg2): {'type': 'Polygon', 'coordinates': [[[12.456860516996768, 45.12551356202371], [13.852592618382664, 45.148073182871244], [13.87191870410008, 44.15979663371134], [12.499651613106883, 44.137996748196564], [12.456860516996768, 45.12551356202371]]]}
# geom bounds: (12.456860516996768, 44.137996748196564, 13.87191870410008, 45.148073182871244)

# %%
# Convert to reflectance (0–1)
rgb = np.dstack([
    ds['r10m']['b04'].values.astype(np.float32) / 10000,  # Red
    ds['r10m']['b03'].values.astype(np.float32) / 10000,  # Green
    ds['r10m']['b02'].values.astype(np.float32) / 10000   # Blue
])

# Per-channel percentile stretch, ignoring NaNs
rgb_stretched = np.zeros_like(rgb, dtype=np.float32)
for i in range(3):
    band = rgb[:, :, i]
    p_low, p_high = np.nanpercentile(band, (1, 99))  # NaN-safe
    scale = p_high - p_low if (p_high - p_low) != 0 else 1e-6
    rgb_stretched[:, :, i] = np.clip((band - p_low) / scale, 0, 1)

# Display
plt.figure(figsize=(12, 8))
plt.imshow(rgb_stretched)
plt.axis('off')
plt.title('Sentinel-2 RGB Composite (1–99% Stretch)')
plt.show()

# %%
# Plot AMEI

red = ds['r20m']['b04'].values.astype(np.float32) / 10000
green = ds['r20m']['b03'].values.astype(np.float32) / 10000
nir = ds['r20m']['b8a'].values.astype(np.float32) / 10000
swir = ds['r20m']['b12'].values.astype(np.float32) / 10000

epsilon = 1e-6  # Small constant to avoid division by zero
denominator = green + (0.25 * swir)

amei = np.full_like(red, np.nan, dtype=np.float32)
# Mask pixels where denominator is too small or NaN
valid_mask = (denominator > epsilon) & np.isfinite(denominator)
amei[valid_mask] = ((2 * red[valid_mask]) + nir[valid_mask] - (2 * swir[valid_mask])) / denominator[valid_mask]
amei_filtered = np.where((amei < 10) & np.isfinite(amei), amei, np.nan)

# # Define mucilage threshold
# threshold = 3

# # Create mask for mucilage pixels
# mucilage_mask = (amei_masked > threshold)

# Plot AMEI full range with masked NaNs
plt.figure(figsize=(12,8))
cmap = plt.cm.turbo
cmap.set_bad(color='black')  # NaNs shown as black

im = plt.imshow(amei_filtered, cmap=cmap)
plt.colorbar(im, label='AMEI Index')

# Overlay mucilage pixels in red (alpha for transparency)
# plt.imshow(np.ma.masked_where(~mucilage_mask, mucilage_mask), cmap='Reds', alpha=0.6)

plt.title('AMEI Index with Mucilage Highlighted')
plt.axis('off')
plt.show()

# %%
# Create and plot chunks

band = "b02"
res = "10m"
chunk_size_y, chunk_size_x, nb_chunks_y, nb_chunks_x = get_chunk_info(data_tree=dt, band=band, res=res)
plot_all_chunks(dt, band, res, chunk_size_y, chunk_size_x, nb_chunks_y, nb_chunks_x, cmap="viridis", verbose= True, figsize_scale=3)
# Out:
# Chunk size: y=1830, x=1830
# Number of chunks: y=6, x=6
